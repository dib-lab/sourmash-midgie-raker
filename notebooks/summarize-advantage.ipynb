# %% [markdown]
# TODO:
# - plot stdev also
# - indicate threshold cutoff on plot?
# - may do only those with little novelty

# %%
ls
# Out:
# Snakefile              metags.mf.csv  summarize-advantage.ipynb  summary.csv
# make-top-picklist.py*  picklists/     summarize-results.py*
# manifests/             results/       summarize-results.py~

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('summary.csv')

# %%
df
# Out:
#               mag  mean_advantage  std_advantage  max_cont
# 0     AtH_MAG2234        0.998472            0.0  0.998472
# 1     AtH_MAG6233        0.994755            0.0  0.994755
# 2     AtH_MAG7634        0.993943            0.0  0.993943
# 3      AtH_MAG697        0.993393            0.0  0.993393
# 4    AtH_MAG10447        0.991711            0.0  0.991711
# ..            ...             ...            ...       ...
# 945   AtH_MAG7521       -0.706181            0.0  0.128571
# 946   AtH_MAG1898       -0.715160            0.0  0.195939
# 947    AtH_MAG915       -0.752437            0.0  0.147563
# 948   AtH_MAG1033       -0.759352            0.0  0.102362
# 949    AtH_MAG440       -0.772106            0.0  0.147310
#
# [950 rows x 4 columns]

# %%
plt.plot(df.index, df.mean_advantage, 'b-', label='mean of differential containment (MAG vs GTDB)')
plt.plot(df.index, df.max_cont, 'r.', label='best MAG containment across all metags', alpha=0.2)
plt.plot([0, max(df.index)], [0, 0], 'g--', label='(0 line: no advantage from MAGs)')
plt.legend(loc='lower left')
plt.xlabel('MAG rank (sorted by advantage)')
plt.ylabel('avg advantage of MAG containment vs best GTDB match')
plt.savefig('advantage.png')
